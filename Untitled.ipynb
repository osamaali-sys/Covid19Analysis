# %%
# Import libraries
import numpy as np 
import pandas as pd 
import plotly as py
import plotly.express as px
import matplotlib as plt
import plotly.graph_objs as go
from plotly.subplots import make_subplots
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df= pd.read_csv('dataset/COVID19_line_list_data.csv')
df
# Out:
#         id  case_in_country reporting date  Unnamed: 3  \
# 0        1              NaN      1/20/2020         NaN
# 1        2              NaN      1/20/2020         NaN
# 2        3              NaN      1/21/2020         NaN
# 3        4              NaN      1/21/2020         NaN
# 4        5              NaN      1/21/2020         NaN
# ...    ...              ...            ...         ...
# 1080  1081              2.0      2/25/2020         NaN
# 1081  1082              1.0      2/24/2020         NaN
# 1082  1083              1.0      2/26/2020         NaN
# 1083  1084              1.0      2/25/2020         NaN
# 1084  1085              1.0      2/25/2020         NaN
#
#                                                 summary             location  \
# 0     First confirmed imported COVID-19 pneumonia pa...  Shenzhen, Guangdong
# 1     First confirmed imported COVID-19 pneumonia pa...             Shanghai
# ...

# %%
df.plot()

# %%
df.isnull()
# Out:
#          id  case_in_country  reporting date  Unnamed: 3  summary  location  \
# 0     False             True           False        True    False     False
# 1     False             True           False        True    False     False
# 2     False             True           False        True    False     False
# 3     False             True           False        True    False     False
# 4     False             True           False        True    False     False
# ...     ...              ...             ...         ...      ...       ...
# 1080  False            False           False        True    False     False
# 1081  False            False           False        True    False     False
# 1082  False            False           False        True    False     False
# 1083  False            False           False        True    False     False
# 1084  False            False           False        True    False     False
#
# ...

# %%
df.isnull().sum()
# Out:
# id                          0
# case_in_country           197
# reporting date              1
# Unnamed: 3               1085
# summary                     5
# location                    0
# country                     0
# gender                    183
# age                       242
# symptom_onset             522
# If_onset_approximated     525
# hosp_visit_date           578
# exposure_start            957
# exposure_end              744
# visiting Wuhan              0
# from Wuhan                  4
# death                       0
# recovered                   0
# symptom                   815
# source                      0
# link                        0
# Unnamed: 21              1085
# Unnamed: 22              1085
# Unnamed: 23              1085
# Unnamed: 24              1085
# Unnamed: 25              1085
# Unnamed: 26              1085
# dtype: int64

# %%
df = df.drop(columns = ['Unnamed: 3','case_in_country','id','Unnamed: 21','Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26'])
df
# Out:
#      reporting date                                            summary  \
# 0         1/20/2020  First confirmed imported COVID-19 pneumonia pa...
# 1         1/20/2020  First confirmed imported COVID-19 pneumonia pa...
# 2         1/21/2020  First confirmed imported cases in Zhejiang: pa...
# 3         1/21/2020  new confirmed imported COVID-19 pneumonia in T...
# 4         1/21/2020  new confirmed imported COVID-19 pneumonia in T...
# ...             ...                                                ...
# 1080      2/25/2020  new COVID-19 patient confirmed in Austria: 24,...
# 1081      2/24/2020  new COVID-19 patient confirmed in Afghanistan:...
# 1082      2/26/2020  new COVID-19 patient confirmed in Algeria: mal...
# 1083      2/25/2020  new COVID-19 patient confirmed in Croatia: mal...
# 1084      2/25/2020  new COVID-19 patient confirmed in Switzerland:...
#
#                  location      country  gender   age symptom_onset  \
# ...

# %%
df = df.rename(columns={'reporting date':'reporting_date'})
df.head()
# Out:
#   reporting_date                                            summary  \
# 0      1/20/2020  First confirmed imported COVID-19 pneumonia pa...
# 1      1/20/2020  First confirmed imported COVID-19 pneumonia pa...
# 2      1/21/2020  First confirmed imported cases in Zhejiang: pa...
# 3      1/21/2020  new confirmed imported COVID-19 pneumonia in T...
# 4      1/21/2020  new confirmed imported COVID-19 pneumonia in T...
#
#               location country  gender   age symptom_onset  \
# 0  Shenzhen, Guangdong   China    male  66.0      01/03/20
# 1             Shanghai   China  female  56.0     1/15/2020
# 2             Zhejiang   China    male  46.0      01/04/20
# 3              Tianjin   China  female  60.0           NaN
# 4              Tianjin   China    male  58.0           NaN
#
#    If_onset_approximated hosp_visit_date exposure_start exposure_end  \
# 0                    0.0        01/11/20     12/29/2019     01/04/20
# ...

# %%
df = df.dropna(subset = ['reporting_date', 'age'])
df
# Out:
#      reporting_date                                            summary  \
# 0         1/20/2020  First confirmed imported COVID-19 pneumonia pa...
# 1         1/20/2020  First confirmed imported COVID-19 pneumonia pa...
# 2         1/21/2020  First confirmed imported cases in Zhejiang: pa...
# 3         1/21/2020  new confirmed imported COVID-19 pneumonia in T...
# 4         1/21/2020  new confirmed imported COVID-19 pneumonia in T...
# ...             ...                                                ...
# 1052      2/21/2020  new confirmed COVID-19 patient in Lebanon: fem...
# 1079      2/25/2020  new COVID-19 patient confirmed in Austria: 24,...
# 1080      2/25/2020  new COVID-19 patient confirmed in Austria: 24,...
# 1081      2/24/2020  new COVID-19 patient confirmed in Afghanistan:...
# 1084      2/25/2020  new COVID-19 patient confirmed in Switzerland:...
#
#                  location      country  gender   age symptom_onset  \
# ...

# %%
df.plot(kind='scatter',
       x='reporting_date',
       y= 'age')
